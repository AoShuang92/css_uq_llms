# %%
# %cd UQ-NLG/
# Out:
# /data/user-data/sa25729/GPT/proposed_UQ_NLG/UQ-NLG

# %%
import pandas as pd

data_path = 'NLGUQ/output/gpt-3.5-turbo_coqa_10/0.pkl'
demo_data = pd.read_pickle(data_path)
demo_data[0]
# Out:
# {'prompt': 'Once upon a time, in a barn near a farm house, there lived a little white kitten named Cotton. Cotton lived high up in a nice warm place above the barn where all of the farmer\'s horses slept. But Cotton wasn\'t alone in her little home above the barn, oh no. She shared her hay bed with her mommy and 5 other sisters. All of her sisters were cute and fluffy, like Cotton. But she was the only white one in the bunch. The rest of her sisters were all orange with beautiful white tiger stripes like Cotton\'s mommy. Being different made Cotton quite sad. She often wished she looked like the rest of her family. So one day, when Cotton found a can of the old farmer\'s orange paint, she used it to paint herself like them. When her mommy and sisters found her they started laughing. \n\n"What are you doing, Cotton?!" \n\n"I only wanted to be more like you". \n\nCotton\'s mommy rubbed her face on Cotton\'s and said "Oh Cotton, but your fur is so pretty and special, like you. We would 
# ...

# %%
import pandas as pd
data_path = 'NLGUQ/output/llama-13b-hf_coqa_10/0.pkl'
demo_data = pd.read_pickle(data_path)
len(demo_data), demo_data[0]
# Out:
# (7983,
#  {'prompt': tensor([    1,  9038,  2501,   263,   931, 29892,   297,   263,  2594, 29876,
#            2978,   263, 17888,  3699, 29892,   727, 10600,   263,  2217,  4796,
#             413, 16097,  4257, 26783,   880, 29889, 26783,   880, 10600,  1880,
#             701,   297,   263,  7575, 14294,  2058,  2038,   278,  2594, 29876,
#             988,   599,   310,   278,  2215,  1050, 29915, 29879, 15100, 12844,
#             415, 29889,  1205, 26783,   880,  9007, 29915, 29873,  7432,   297,
#             902,  2217,  3271,  2038,   278,  2594, 29876, 29892,  9360,   694,
#           29889,  2296,  7258,   902, 14842,  6592,   411,   902, 16823,  1357,
#             322, 29871, 29945,   916,  9883, 29879, 29889,  2178,   310,   902,
#            9883, 29879,   892,   274,  1082,   322,  1652,  3096, 29891, 29892,
#             763, 26783,   880, 29889,  1205,  1183,   471,   278,   871,  4796,
# ...

# %%
data_path = 'NLGUQ/output/opt-13b_coqa_10/0.pkl'
demo_data = pd.read_pickle(data_path)
demo_data[0]
# Out:
# {'prompt': tensor([    2, 11475,  2115,    10,    86,     6,    11,    10, 15909,   583,
#             10,  3380,   790,     6,    89,  3033,    10,   410,  1104, 35292,
#           1440, 15416,     4, 15416,  3033,   239,    62,    11,    10,  2579,
#           3279,   317,  1065,     5, 15909,   147,    70,     9,     5, 10305,
#             18,  8087, 17931,     4,   125, 15416,   938,    75,  1937,    11,
#             69,   410,   184,  1065,     5, 15909,     6, 14223,   117,     4,
#            264,  1373,    69, 13460,  3267,    19,    69,  3795,  4783,     8,
#            195,    97,  7502,     4,   404,     9,    69,  7502,    58, 11962,
#              8, 33564,     6,   101, 15416,     4,   125,    79,    21,     5,
#            129,  1104,    65,    11,     5,  6900,     4,    20,  1079,     9,
#             69,  7502,    58,    70,  8978,    19,  2721,  1104, 23921, 26224,
#            101, 15416,    18,  3795,  4783,     4,  8374,   430,   156, 15416,
# ...

# %%
import pandas as pd
data_path = 'NLGUQ/output/llama-13b-hf_triviaqa_10/0.pkl'
demo_data = pd.read_pickle(data_path)
len(demo_data),demo_data[0]['answer']
# Out:
# (9960, 'David Seville')

# %%
import numpy as np
ans_temp = demo_data[0]['answer']
print(len(ans_temp.split(' ')))
all_length = []
for d in demo_data:
    temp_len = len(d['answer'].split(' '))
    all_length.append(temp_len)


np.array(all_length).max(), np.array(all_length).min(), np.array(all_length).mean()
# Out:
# (49, 1, 1.7028112449799198)

# %%
data_path = 'NLGUQ/output/llama-13b-hf_nq_open_10/0.pkl'
demo_data = pd.read_pickle(data_path)
demo_data[0]
# Out:
# {'prompt': tensor([    1,   673,  1438,  5155, 29901,    13, 29984, 29901,  1058,  3732,
#            701,   278,  2106, 18701,   297, 17626,   423,    13, 29909, 29901,
#           4095,   943,   322,  2225, 16719,    13, 29984, 29901,   746,   947,
#           1855,   931,   411, 11118,   611,  2276,  2041,  1250,    13, 29909,
#          29901,  3979, 30081, 29929, 29892, 30081, 29906, 29900, 29896, 29947,
#             13, 29984, 29901,   988,  1258,   278, 16549,  7902,  2185, 12561,
#           2041,   515,    13, 29909, 29901,   278, 16624,  1387, 11211,  4565,
#            631,  2834,    13, 29984, 29901,   825,   437,   366,  1246,   263,
#           2318,   310,   321,  1379,    13, 29909, 29901,  6592,    13, 29984,
#          29901,  1058,  5456,   278,  8158,   363, 10655,  9301,  6416,   449,
#             13, 29909, 29901, 10980,   484,  7392,  1725,    13, 29984, 29901,
#            746,   471,   278,  1833,   931,  5019,   471,   373,   278, 18786,
# ...

# %%
data_path_ = 'notebook/demo_data.pkl'
demo_data_ = pd.read_pickle(data_path_)
demo_data_[0]
# Out:
# {'prompt': 'Answer these questions:\nQ: In Scotland a bothy/bothie is a?\nA: House\nQ: Which 2008 Western film starred Ed Harris and Viggo Mortensen as lawmen, Jeremy Irons as a rancher and Renee Zellweger as a piano-playing widow?\nA:',
#  'id': 'qw_8385',
#  'question': 'Which 2008 Western film starred Ed Harris and Viggo Mortensen as lawmen, Jeremy Irons as a rancher and Renee Zellweger as a piano-playing widow?',
#  'answer': 'Appaloosa',
#  'generations': {'text_cleaned': [' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa',
#    ' Appaloosa'],
#   'text': [' Appaloosa\n',
#    ' Appaloosa\n',
#    ' Appaloosa\n',
#    ' Appaloosa\n',
#    ' Appaloosa\n',
#    ' Appaloosa\n',
# ...
